# %% [markdown]
# <a href="https://colab.research.google.com/github/Lautaro1106/n8n-proyectos-prueba/blob/main/echomimic2_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/antgroup/echomimic_v2
# %cd /content/echomimic_v2

# !apt install aria2 -qqy

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/BadToBest/EchoMimicV2/resolve/main/denoising_unet.pth -d /content/echomimic_v2/pretrained_weights -o denoising_unet.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/BadToBest/EchoMimicV2/resolve/main/motion_module.pth -d /content/echomimic_v2/pretrained_weights -o motion_module.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/BadToBest/EchoMimicV2/resolve/main/reference_unet.pth -d /content/echomimic_v2/pretrained_weights -o reference_unet.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/BadToBest/EchoMimicV2/resolve/main/pose_encoder.pth -d /content/echomimic_v2/pretrained_weights -o pose_encoder.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://openaipublic.azureedge.net/main/whisper/models/65147644a518d12f04e32d6f3b26facc3f8dd46e5390956a9424a650c0ce22b9/tiny.pt -d /content/echomimic_v2/pretrained_weights/audio_processor -o whisper_tiny.pt
# !git clone https://huggingface.co/lambdalabs/sd-image-variations-diffusers /content/echomimic_v2/pretrained_weights/sd-image-variations-diffusers
# !git clone https://huggingface.co/stabilityai/sd-vae-ft-mse /content/echomimic_v2/pretrained_weights/sd-vae-ft-mse

# !pip install omegaconf diffusers>=0.30.2 einops huggingface-hub==0.23.2 ffmpeg imageio-ffmpeg ffmpeg-python av decord transformers matplotlib opencv-python moviepy==1.0.3 accelerate

# !wget https://www.johnvansickle.com/ffmpeg/old-releases/ffmpeg-4.4-amd64-static.tar.xz -O /content/ffmpeg-4.4-amd64-static.tar.xz
# !mkdir -p /content/ffmpeg
# !tar -xf /content/ffmpeg-4.4-amd64-static.tar.xz -C /content/ffmpeg --strip-components=1
# Out:
# /content
# fatal: destination path 'echomimic_v2' already exists and is not an empty directory.
# /content/echomimic_v2
# aria2 is already the newest version (1.36.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 4b3cca|OK  |       0B/s|/content/echomimic_v2/pretrained_weights/denoising_unet.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e10d51|OK  |       0B/s|/content/echomimic_v2/pretrained_weights/motion_module.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a18b24|OK  |       0B/s|/content/echomimic_v2/pretrained_weights/reference_unet.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 266dfb|OK  |       0B/s|/content/echomimic_v2/pretrained_weights/pose_encoder.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 71ca15|OK  |       0B/s|/content/echomimic_v2/pretrained_weights/audio_processor/whisper_tiny.pt
#
# Status Legend:
# (OK):download completed.
# fatal: destination path '/content/echomimic_v2/pretrained_weights/sd-image-variations-diffusers' already exists and is not an empty directory.
# fatal: destination path '/content/echomimic_v2/pretrained_weights/sd-vae-ft-mse' already exists and is not an empty directory.

# %%
# %cd /content/echomimic_v2

# Definimos tus archivos para que el comando sea fácil de leer
FOTO = "/content/1765120293417.jpg"
AUDIO = "/content/ElevenLabs1.mp3"

# Ejecutamos la inferencia (Audio-Driven)
# !python infer.py --refimg_name "{FOTO}" --audio_name "{AUDIO}" --visualize
# Out:
# /content/echomimic_v2
# 2026-02-15 00:15:58.892577: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771114558.913662    4427 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771114558.920794    4427 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771114558.939018    4427 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771114558.939042    4427 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771114558.939046    4427 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771114558.939049    4427 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-15 00:15:58.943777: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/diffusers/utils/outputs.py:63: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# Traceback (most recent call last):
#   File "/content/echomimic_v2/infer.py", line 15, in <module>
#     from src.models.unet_2d_condition import UNet2DConditionModel
#   File "/content/echomimic_v2/src/models/unet_2d_condition.py", line 19, in <module>
#     from diffusers.models.embeddings import (
# ImportError: cannot import name 'GLIGENTextBoundingboxProjection' from 'diffusers.models.embeddings' (/usr/local/lib/python3.12/dist-packages/diffusers/models/embeddings.py)

# %%
# Rutas de tus archivos para EchoMimic
image_path = '/content/1765120293417.jpg'
audio_path = '/content/ElevenLabs1.mp3'
